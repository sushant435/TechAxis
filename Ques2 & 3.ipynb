# %%
import pandas as pd

# %%
#read csv file from the path
df = pd.read_csv(r"C:\Users\cptsp\Downloads\archive\airport_traffic_2025.csv")

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of         YEAR  MONTH_NUM MONTH_MON    FLT_DATE APT_ICAO           APT_NAME  \
# 0       2025          1       JAN  2025-01-01     LATI             Tirana
# 1       2025          1       JAN  2025-01-01     UDYZ            Yerevan
# 2       2025          1       JAN  2025-01-01     LOWG               Graz
# 3       2025          1       JAN  2025-01-01     LOWI          Innsbruck
# 4       2025          1       JAN  2025-01-01     LOWK         Klagenfurt
# ...      ...        ...       ...         ...      ...                ...
# 116015  2025         12       DEC  2025-12-31     EGNX      East Midlands
# 116016  2025         12       DEC  2025-12-31     EGPD           Aberdeen
# 116017  2025         12       DEC  2025-12-31     EGPF            Glasgow
# 116018  2025         12       DEC  2025-12-31     EGPH          Edinburgh
# 116019  2025         12       DEC  2025-12-31     EGSS  London - Stansted
#
# ...

# %%
#find title of the columns
print(df.columns.tolist())
# Out:
# ['YEAR', 'MONTH_NUM', 'MONTH_MON', 'FLT_DATE', 'APT_ICAO', 'APT_NAME', 'STATE_NAME', 'FLT_DEP_1', 'FLT_ARR_1', 'FLT_TOT_1', 'FLT_DEP_IFR_2', 'FLT_ARR_IFR_2', 'FLT_TOT_IFR_2']

# %%
#Check for Missing Values
df.isnull().sum()
# Out:
# YEAR                 0
# MONTH_NUM            0
# MONTH_MON            0
# FLT_DATE             0
# APT_ICAO             0
# APT_NAME             0
# STATE_NAME           0
# FLT_DEP_1            0
# FLT_ARR_1            0
# FLT_TOT_1            0
# FLT_DEP_IFR_2    81892
# FLT_ARR_IFR_2    81892
# FLT_TOT_IFR_2    81892
# dtype: int64

# %%
# Checking how many data is missing
df.isnull().mean() * 100
# Out:
# YEAR              0.000000
# MONTH_NUM         0.000000
# MONTH_MON         0.000000
# FLT_DATE          0.000000
# APT_ICAO          0.000000
# APT_NAME          0.000000
# STATE_NAME        0.000000
# FLT_DEP_1         0.000000
# FLT_ARR_1         0.000000
# FLT_TOT_1         0.000000
# FLT_DEP_IFR_2    70.584382
# FLT_ARR_IFR_2    70.584382
# FLT_TOT_IFR_2    70.584382
# dtype: float64

# %%
# Dropping Columns with too much missing data (70.58%)
df = df.drop(columns=['FLT_DEP_IFR_2', 'FLT_ARR_IFR_2', 'FLT_TOT_IFR_2'])

# %%
#Checking for duplicate row
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 116015    False
# 116016    False
# 116017    False
# 116018    False
# 116019    False
# Length: 116020, dtype: bool

# %%
# Show all the duplicate row
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [YEAR, MONTH_NUM, MONTH_MON, FLT_DATE, APT_ICAO, APT_NAME, STATE_NAME, FLT_DEP_1, FLT_ARR_1, FLT_TOT_1]
# Index: []

# %%
# #remove duplicates if any
# df = df.drop_duplicates()

# # Drop rows with missing values
# df_drop = df.dropna()

# # Drop columns with missing values
# df_drop_col = df.dropna(axis=1)
