# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
#read csv file from the path
df = pd.read_csv(r"C:\Users\cptsp\Downloads\archive\health_dataset.csv")

# %%
#find title of the columns
print(df.columns.tolist())
# Out:
# ['ID', 'Country', 'Year', 'Age', 'Gender', 'Age_Group', 'HbA1c', 'HDL', 'LDL', 'TG', 'TG_HDL_Ratio', 'Fasting_Insulin', 'HOMA_IR', 'Diabetic', 'Insulin_Resistant', 'Heart_Risk']

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of             ID        Country  Year  Age  Gender Age_Group  HbA1c    HDL  \
# 0            1  United States  2005   67  Female   Elderly   7.32  45.24
# 1            2  United States  2005   64  Female   Elderly   7.09  38.66
# 2            3  United States  2005   28    Male     Adult   7.56  41.43
# 3            4  United States  2005    8    Male     Child   5.88  26.34
# 4            5  United States  2005   11  Female     Child   7.55  60.34
# ...        ...            ...   ...  ...     ...       ...    ...    ...
# 189995  189996          Nauru  2024   18  Female      Teen   8.38  44.22
# 189996  189997          Nauru  2024   20  Female     Adult   6.30  49.18
# 189997  189998          Nauru  2024   64    Male   Elderly   8.40  49.59
# 189998  189999          Nauru  2024   32    Male     Adult   7.56  46.20
# 189999  190000          Nauru  2024   15  Female      Teen   5.54  39.99
#
# ...
